# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('minimumwagepart3.csv')

# %%
df
# Out:
#         Unnamed: 0                       date  \
# 0                0  2023-02-12 23:27:26+00:00
# 1                1  2023-02-12 23:21:58+00:00
# 2                2  2023-02-12 23:13:45+00:00
# 3                3  2023-02-12 23:04:45+00:00
# 4                4  2023-02-12 22:57:51+00:00
# ...            ...                        ...
# 272198      272198  2022-10-15 00:31:42+00:00
# 272199      272199  2022-10-15 00:30:59+00:00
# 272200      272200  2022-10-15 00:27:09+00:00
# 272201      272201  2022-10-15 00:21:38+00:00
# 272202      272202  2022-10-15 00:02:53+00:00
#
#                                                rawContent                   id
# 0       @medyaadami Yahu ben asgari ücret ile geçimini...  1624913098388774919
# 1       @zaferozturkfk @TOZOK1951 Özel okul öğretmenle...  1624911722640293889
# 2       Yandaş medya el ele vermiş "emekliye gün doğdu...  1624909655813107715
# 3       @kilicdarogluk Ekonomiyi çökerttiler derken Ak...  1624907389227921408
# 4       @suleerenates @ErSalih55 @yazilama @Besiktas @...  1624905652794449921
# ...                                                   ...                  ...
# 272198  Asgari ücret 2 senede 2 katına çıktı ama işsiz...  1581080337995960321
# 272199  millet 10 bine az demiş ulan 2 aylık asgari üc...  1581080158286491648
# 272200  @CreeWarrior2010 Türkiye'de asgari ücret ile b...  1581079194452127744
# 272201  @adanaliahmo @ebrukucukaydinn Cahil adam. Hesa...  1581077804392726528
# 272202  @b_ysabri La meta devlet yeteri kadar yani geç...  1581073086878650369
#
# [272203 rows x 4 columns]

# %%
tweets=df['rawContent']

# %%
tweets
# Out:
# 0         @medyaadami Yahu ben asgari ücret ile geçimini...
# 1         @zaferozturkfk @TOZOK1951 Özel okul öğretmenle...
# 2         Yandaş medya el ele vermiş "emekliye gün doğdu...
# 3         @kilicdarogluk Ekonomiyi çökerttiler derken Ak...
# 4         @suleerenates @ErSalih55 @yazilama @Besiktas @...
#                                 ...
# 272198    Asgari ücret 2 senede 2 katına çıktı ama işsiz...
# 272199    millet 10 bine az demiş ulan 2 aylık asgari üc...
# 272200    @CreeWarrior2010 Türkiye'de asgari ücret ile b...
# 272201    @adanaliahmo @ebrukucukaydinn Cahil adam. Hesa...
# 272202    @b_ysabri La meta devlet yeteri kadar yani geç...
# Name: rawContent, Length: 272203, dtype: object

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline

# %%
model = AutoModelForSequenceClassification.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
tokenizer = AutoTokenizer.from_pretrained("savasy/bert-base-turkish-sentiment-cased")
sa= pipeline("sentiment-analysis", tokenizer=tokenizer, model=model)

# %%
sentiment=[]

# %%
for i in range(len(tweets)):
    if i % 10_000 == 0:
        print(f"{i}/{len(tweets)} | {i/len(tweets)*100:.2f}%")
    sentiment.append(sa(tweets[i]))

print(f"{len(tweets)}/{len(tweets)} | {len(tweets)/len(tweets)*100:.2f}%")
# Out:
# 0/272203 | 0.00%
# 10000/272203 | 3.67%
# 20000/272203 | 7.35%
# 30000/272203 | 11.02%
# 40000/272203 | 14.69%
# 50000/272203 | 18.37%
# 60000/272203 | 22.04%
# 70000/272203 | 25.72%
# 80000/272203 | 29.39%
# 90000/272203 | 33.06%
# 100000/272203 | 36.74%
# 110000/272203 | 40.41%
# 120000/272203 | 44.08%
# 130000/272203 | 47.76%
# 140000/272203 | 51.43%
# 150000/272203 | 55.11%
# 160000/272203 | 58.78%
# 170000/272203 | 62.45%
# 180000/272203 | 66.13%
# 190000/272203 | 69.80%
# 200000/272203 | 73.47%
# 210000/272203 | 77.15%
# 220000/272203 | 80.82%
# 230000/272203 | 84.50%
# 240000/272203 | 88.17%
# 250000/272203 | 91.84%
# 260000/272203 | 95.52%
# 270000/272203 | 99.19%
# 272203/272203 | 100.00%

# %%
sentiment
# Out:
# [[{'label': 'negative', 'score': 0.9990419745445251}],
#  [{'label': 'negative', 'score': 0.9296393394470215}],
#  [{'label': 'negative', 'score': 0.9926839470863342}],
#  [{'label': 'negative', 'score': 0.9979596138000488}],
#  [{'label': 'negative', 'score': 0.8927289843559265}],
#  [{'label': 'negative', 'score': 0.7306048274040222}],
#  [{'label': 'negative', 'score': 0.964428722858429}],
#  [{'label': 'negative', 'score': 0.9952502250671387}],
#  [{'label': 'negative', 'score': 0.9976060390472412}],
#  [{'label': 'negative', 'score': 0.9979637861251831}],
#  [{'label': 'negative', 'score': 0.9976735711097717}],
#  [{'label': 'negative', 'score': 0.6465917825698853}],
#  [{'label': 'negative', 'score': 0.972405195236206}],
#  [{'label': 'negative', 'score': 0.7929326295852661}],
#  [{'label': 'positive', 'score': 0.9591180682182312}],
#  [{'label': 'negative', 'score': 0.9976032376289368}],
#  [{'label': 'negative', 'score': 0.9802029132843018}],
#  [{'label': 'negative', 'score': 0.9747262597084045}],
#  [{'label': 'negative', 'score': 0.621238648891449}],
#  [{'label': 'negative', 'score': 0.9755520224571228}],
#  [{'label': 'negative', 'score': 0.7501649856567383}],
#  [{'label': 'negative', 'score': 0.6405531167984009}],
#  [{'label': 'negative', 'score': 0.990136444568634}],
#  [{'label': 'negative', 'score': 0.8812974095344543}],
#  [{'label': 'negative', 'score': 0.9977409839630127}],
#  [{'label': 'negative', 'score': 0.9114224910736084}],
#  [{'label': 'negative', 'score': 0.9949106574058533}],
#  [{'label': 'negative', 'score': 0.9938951134681702}],
#  [{'label': 'positive', 'score': 0.9311590790748596}],
#  [{'label': 'negative', 'score': 0.9951687455177307}],
#  [{'label': 'positive', 'score': 0.8542147874832153}],
#  [{'label': 'negative', 'score': 0.9684345126152039}],
#  [{'label': 'negative', 'score': 0.9881507158279419}],
#  [{'label': 'negative', 'score': 0.997525155544281}],
#  [{'label': 'negative', 'score': 0.996729850769043}],
#  [{'label': 'positive', 'score': 0.6140349507331848}],
#  [{'label': 'negative', 'score': 0.9282197952270508}],
#  [{'label': 'negative', 'score': 0.9914740324020386}],
#  [{'label': 'negative', 'score': 0.9532833099365234}],
#  [{'label': 'negative', 'score': 0.9843155741691589}],
#  [{'label': 'negative', 'score': 0.8680068254470825}],
#  [{'label': 'negative', 'score': 0.9976925849914551}],
#  [{'label': 'positive', 'score': 0.9916802048683167}],
#  [{'label': 'negative', 'score': 0.8501730561256409}],
#  [{'label': 'negative', 'score': 0.9782800674438477}],
#  [{'label': 'negative', 'score': 0.9779127836227417}],
#  [{'label': 'negative', 'score': 0.9123246669769287}],
#  [{'label': 'negative', 'score': 0.9958444237709045}],
#  [{'label': 'negative', 'score': 0.9139151573181152}],
#  [{'label': 'negative', 'score': 0.8958433270454407}],
#  [{'label': 'negative', 'score': 0.7481871247291565}],
#  [{'label': 'negative', 'score': 0.950315535068512}],
#  [{'label': 'negative', 'score': 0.8653945922851562}],
#  [{'label': 'negative', 'score': 0.8969154357910156}],
#  [{'label': 'negative', 'score': 0.8040979504585266}],
#  [{'label': 'negative', 'score': 0.9951725602149963}],
#  [{'label': 'negative', 'score': 0.9916806817054749}],
#  [{'label': 'positive', 'score': 0.5373102426528931}],
#  [{'label': 'negative', 'score': 0.9088097214698792}],
#  [{'label': 'negative', 'score': 0.9928573369979858}],
#  [{'label': 'negative', 'score': 0.7901648283004761}],
#  [{'label': 'negative', 'score': 0.9966121315956116}],
#  [{'label': 'negative', 'score': 0.846846878528595}],
#  [{'label': 'negative', 'score': 0.9520136117935181}],
#  [{'label': 'negative', 'score': 0.9967555403709412}],
#  [{'label': 'negative', 'score': 0.956376314163208}],
#  [{'label': 'negative', 'score': 0.9932957291603088}],
#  [{'label': 'negative', 'score': 0.6408909559249878}],
#  [{'label': 'negative', 'score': 0.9937268495559692}],
#  [{'label': 'negative', 'score': 0.9627768397331238}],
#  [{'label': 'negative', 'score': 0.8854232430458069}],
#  [{'label': 'negative', 'score': 0.9991439580917358}],
#  [{'label': 'negative', 'score': 0.8902741074562073}],
#  [{'label': 'negative', 'score': 0.9959379434585571}],
#  [{'label': 'negative', 'score': 0.9964852333068848}],
#  [{'label': 'negative', 'score': 0.7109686136245728}],
#  [{'label': 'negative', 'score': 0.9863799214363098}],
#  [{'label': 'positive', 'score': 0.7661468982696533}],
#  [{'label': 'negative', 'score': 0.9567650556564331}],
#  [{'label': 'negative', 'score': 0.9947943091392517}],
#  [{'label': 'negative', 'score': 0.995617151260376}],
#  [{'label': 'negative', 'score': 0.8040979504585266}],
#  [{'label': 'positive', 'score': 0.7456556558609009}],
#  [{'label': 'negative', 'score': 0.7651044726371765}],
#  [{'label': 'negative', 'score': 0.9699237942695618}],
#  [{'label': 'negative', 'score': 0.9949943423271179}],
#  [{'label': 'negative', 'score': 0.9945524334907532}],
#  [{'label': 'negative', 'score': 0.9977743029594421}],
#  [{'label': 'negative', 'score': 0.9911450743675232}],
#  [{'label': 'negative', 'score': 0.9659774303436279}],
#  [{'label': 'negative', 'score': 0.9619878530502319}],
#  [{'label': 'positive', 'score': 0.7680001258850098}],
#  [{'label': 'negative', 'score': 0.6487547755241394}],
#  [{'label': 'negative', 'score': 0.8932948708534241}],
#  [{'label': 'negative', 'score': 0.8430461883544922}],
#  [{'label': 'negative', 'score': 0.9909443855285645}],
#  [{'label': 'negative', 'score': 0.9406850934028625}],
#  [{'label': 'positive', 'score': 0.6743817329406738}],
#  [{'label': 'negative', 'score': 0.5867429971694946}],
#  [{'label': 'negative', 'score': 0.7554450035095215}],
#  [{'label': 'negative', 'score': 0.9973282814025879}],
#  [{'label': 'negative', 'score': 0.9766185283660889}],
#  [{'label': 'negative', 'score': 0.9963123202323914}],
#  [{'label': 'negative', 'score': 0.806024968624115}],
#  [{'label': 'negative', 'score': 0.996136486530304}],
#  [{'label': 'negative', 'score': 0.8975818753242493}],
#  [{'label': 'negative', 'score': 0.9943839311599731}],
#  [{'label': 'negative', 'score': 0.9975271821022034}],
#  [{'label': 'negative', 'score': 0.9725435376167297}],
#  [{'label': 'negative', 'score': 0.9971067309379578}],
#  [{'label': 'negative', 'score': 0.9972010850906372}],
#  [{'label': 'negative', 'score': 0.8608539700508118}],
#  [{'label': 'negative', 'score': 0.8285898566246033}],
#  [{'label': 'negative', 'score': 0.9967155456542969}],
#  [{'label': 'positive', 'score': 0.5847315788269043}],
#  [{'label': 'negative', 'score': 0.9974532723426819}],
#  [{'label': 'negative', 'score': 0.9969779253005981}],
#  [{'label': 'negative', 'score': 0.9820401072502136}],
#  [{'label': 'negative', 'score': 0.698023796081543}],
#  [{'label': 'negative', 'score': 0.9935117363929749}],
#  [{'label': 'negative', 'score': 0.9980079531669617}],
#  [{'label': 'negative', 'score': 0.9571777582168579}],
#  [{'label': 'negative', 'score': 0.9990099668502808}],
#  [{'label': 'negative', 'score': 0.9962049126625061}],
#  [{'label': 'negative', 'score': 0.9935542345046997}],
#  [{'label': 'negative', 'score': 0.982647716999054}],
#  [{'label': 'negative', 'score': 0.9944741129875183}],
#  [{'label': 'negative', 'score': 0.9983185529708862}],
#  [{'label': 'negative', 'score': 0.9681338667869568}],
#  [{'label': 'negative', 'score': 0.9858389496803284}],
#  [{'label': 'negative', 'score': 0.9887813925743103}],
#  [{'label': 'negative', 'score': 0.8948237895965576}],
#  [{'label': 'negative', 'score': 0.6189991235733032}],
#  [{'label': 'positive', 'score': 0.531261146068573}],
#  [{'label': 'negative', 'score': 0.971027672290802}],
#  [{'label': 'negative', 'score': 0.8807582259178162}],
#  [{'label': 'negative', 'score': 0.9559229016304016}],
#  [{'label': 'negative', 'score': 0.967410147190094}],
#  [{'label': 'negative', 'score': 0.9713819622993469}],
#  [{'label': 'negative', 'score': 0.9943969249725342}],
#  [{'label': 'negative', 'score': 0.9609677791595459}],
#  [{'label': 'negative', 'score': 0.9553151726722717}],
#  [{'label': 'negative', 'score': 0.6103479862213135}],
#  [{'label': 'negative', 'score': 0.9839630722999573}],
#  [{'label': 'negative', 'score': 0.982105016708374}],
#  [{'label': 'negative', 'score': 0.9973512887954712}],
#  [{'label': 'negative', 'score': 0.9770639538764954}],
#  [{'label': 'negative', 'score': 0.9935731291770935}],
#  [{'label': 'negative', 'score': 0.8300936818122864}],
#  [{'label': 'negative', 'score': 0.9896462559700012}],
#  [{'label': 'negative', 'score': 0.9759842157363892}],
#  [{'label': 'negative', 'score': 0.9971910119056702}],
#  [{'label': 'negative', 'score': 0.9535723328590393}],
#  [{'label': 'negative', 'score': 0.9967114925384521}],
#  [{'label': 'negative', 'score': 0.9936483502388}],
#  [{'label': 'negative', 'score': 0.9970670342445374}],
#  [{'label': 'negative', 'score': 0.9950673580169678}],
#  [{'label': 'negative', 'score': 0.9282722473144531}],
#  [{'label': 'negative', 'score': 0.9697255492210388}],
#  [{'label': 'negative', 'score': 0.9962685108184814}],
#  [{'label': 'negative', 'score': 0.9988664388656616}],
#  [{'label': 'negative', 'score': 0.7013944983482361}],
#  [{'label': 'negative', 'score': 0.9981529116630554}],
#  [{'label': 'negative', 'score': 0.8439823389053345}],
#  [{'label': 'negative', 'score': 0.9759941101074219}],
#  [{'label': 'negative', 'score': 0.9420055150985718}],
#  [{'label': 'negative', 'score': 0.9923088550567627}],
#  [{'label': 'negative', 'score': 0.9002940058708191}],
#  [{'label': 'negative', 'score': 0.9992899894714355}],
#  [{'label': 'negative', 'score': 0.9960804581642151}],
#  [{'label': 'negative', 'score': 0.9825875163078308}],
#  [{'label': 'positive', 'score': 0.9846961498260498}],
#  [{'label': 'positive', 'score': 0.7069888710975647}],
#  [{'label': 'negative', 'score': 0.9936519861221313}],
#  [{'label': 'negative', 'score': 0.9997145533561707}],
#  [{'label': 'negative', 'score': 0.9430684447288513}],
#  [{'label': 'negative', 'score': 0.9879234433174133}],
#  [{'label': 'positive', 'score': 0.9977015852928162}],
#  [{'label': 'negative', 'score': 0.988338828086853}],
#  [{'label': 'negative', 'score': 0.7987455725669861}],
#  [{'label': 'negative', 'score': 0.9984925985336304}],
#  [{'label': 'negative', 'score': 0.9890245795249939}],
#  [{'label': 'negative', 'score': 0.8938928842544556}],
#  [{'label': 'positive', 'score': 0.5543559789657593}],
#  [{'label': 'negative', 'score': 0.9895316362380981}],
#  [{'label': 'negative', 'score': 0.897407591342926}],
#  [{'label': 'negative', 'score': 0.9540374279022217}],
#  [{'label': 'negative', 'score': 0.7818610668182373}],
#  [{'label': 'negative', 'score': 0.8064538836479187}],
#  [{'label': 'negative', 'score': 0.9680831432342529}],
#  [{'label': 'negative', 'score': 0.9915508031845093}],
#  [{'label': 'negative', 'score': 0.9799179434776306}],
#  [{'label': 'negative', 'score': 0.9951664209365845}],
#  [{'label': 'negative', 'score': 0.9969205856323242}],
#  [{'label': 'positive', 'score': 0.7330719232559204}],
#  [{'label': 'positive', 'score': 0.9042753577232361}],
#  [{'label': 'negative', 'score': 0.9360492825508118}],
#  [{'label': 'positive', 'score': 0.9353184103965759}],
#  [{'label': 'negative', 'score': 0.9982852339744568}],
#  [{'label': 'negative', 'score': 0.9974114298820496}],
#  [{'label': 'positive', 'score': 0.8142163157463074}],
#  [{'label': 'negative', 'score': 0.9697045683860779}],
#  [{'label': 'negative', 'score': 0.997871994972229}],
#  [{'label': 'negative', 'score': 0.978839099407196}],
#  [{'label': 'negative', 'score': 0.9695050120353699}],
#  [{'label': 'negative', 'score': 0.8851087093353271}],
#  [{'label': 'negative', 'score': 0.6883876323699951}],
#  [{'label': 'negative', 'score': 0.9968505501747131}],
#  [{'label': 'negative', 'score': 0.9881965517997742}],
#  [{'label': 'negative', 'score': 0.9979402422904968}],
#  [{'label': 'negative', 'score': 0.9890178442001343}],
#  [{'label': 'negative', 'score': 0.9959659576416016}],
#  [{'label': 'negative', 'score': 0.9949843883514404}],
#  [{'label': 'negative', 'score': 0.9989562034606934}],
#  [{'label': 'negative', 'score': 0.9971663355827332}],
#  [{'label': 'negative', 'score': 0.9568548798561096}],
#  [{'label': 'negative', 'score': 0.9297192692756653}],
#  [{'label': 'negative', 'score': 0.9602137804031372}],
#  [{'label': 'negative', 'score': 0.9776943922042847}],
#  [{'label': 'negative', 'score': 0.9947040677070618}],
#  [{'label': 'negative', 'score': 0.9962994456291199}],
#  [{'label': 'negative', 'score': 0.99562668800354}],
#  [{'label': 'negative', 'score': 0.9906533360481262}],
#  [{'label': 'negative', 'score': 0.9933504462242126}],
#  [{'label': 'negative', 'score': 0.9937655925750732}],
#  [{'label': 'positive', 'score': 0.9924679398536682}],
#  [{'label': 'negative', 'score': 0.9941098690032959}],
#  [{'label': 'negative', 'score': 0.9906304478645325}],
#  [{'label': 'negative', 'score': 0.9986679553985596}],
#  [{'label': 'negative', 'score': 0.8745285272598267}],
#  [{'label': 'negative', 'score': 0.9037153124809265}],
#  [{'label': 'negative', 'score': 0.9971404075622559}],
#  [{'label': 'negative', 'score': 0.8439931273460388}],
#  [{'label': 'negative', 'score': 0.998816967010498}],
#  [{'label': 'negative', 'score': 0.7258831858634949}],
#  [{'label': 'negative', 'score': 0.8282477855682373}],
#  [{'label': 'negative', 'score': 0.9866846203804016}],
#  [{'label': 'negative', 'score': 0.9547732472419739}],
#  [{'label': 'negative', 'score': 0.9849222302436829}],
#  [{'label': 'negative', 'score': 0.7806015610694885}],
#  [{'label': 'negative', 'score': 0.8384159207344055}],
#  [{'label': 'negative', 'score': 0.6900432109832764}],
#  [{'label': 'negative', 'score': 0.9557285308837891}],
#  [{'label': 'negative', 'score': 0.9980984330177307}],
#  [{'label': 'negative', 'score': 0.9991894364356995}],
#  [{'label': 'negative', 'score': 0.9217244982719421}],
#  [{'label': 'negative', 'score': 0.9542922973632812}],
#  [{'label': 'negative', 'score': 0.54221510887146}],
#  [{'label': 'negative', 'score': 0.9989281296730042}],
#  [{'label': 'negative', 'score': 0.9966037273406982}],
#  [{'label': 'positive', 'score': 0.7554931640625}],
#  [{'label': 'negative', 'score': 0.9080795049667358}],
#  [{'label': 'positive', 'score': 0.976993203163147}],
#  [{'label': 'negative', 'score': 0.947604775428772}],
#  [{'label': 'negative', 'score': 0.9989843964576721}],
#  [{'label': 'negative', 'score': 0.9874058365821838}],
#  [{'label': 'negative', 'score': 0.9039931297302246}],
#  [{'label': 'negative', 'score': 0.9975268244743347}],
#  [{'label': 'negative', 'score': 0.9887701272964478}],
#  [{'label': 'negative', 'score': 0.9872655868530273}],
#  [{'label': 'negative', 'score': 0.9955908060073853}],
#  [{'label': 'negative', 'score': 0.7720947265625}],
#  [{'label': 'negative', 'score': 0.9989333748817444}],
#  [{'label': 'negative', 'score': 0.9878255724906921}],
#  [{'label': 'negative', 'score': 0.9922423362731934}],
#  [{'label': 'negative', 'score': 0.9980254173278809}],
#  [{'label': 'positive', 'score': 0.8938244581222534}],
#  [{'label': 'negative', 'score': 0.9978013634681702}],
#  [{'label': 'negative', 'score': 0.9604262709617615}],
#  [{'label': 'negative', 'score': 0.8920897245407104}],
#  [{'label': 'negative', 'score': 0.9906304478645325}],
#  [{'label': 'negative', 'score': 0.9988184571266174}],
#  [{'label': 'negative', 'score': 0.9947408437728882}],
#  [{'label': 'negative', 'score': 0.9933841824531555}],
#  [{'label': 'negative', 'score': 0.9494248628616333}],
#  [{'label': 'negative', 'score': 0.5843555927276611}],
#  [{'label': 'negative', 'score': 0.9848697185516357}],
#  [{'label': 'negative', 'score': 0.9522661566734314}],
#  [{'label': 'negative', 'score': 0.9991968274116516}],
#  [{'label': 'negative', 'score': 0.8601616024971008}],
#  [{'label': 'negative', 'score': 0.9959599375724792}],
#  [{'label': 'negative', 'score': 0.8441692590713501}],
#  [{'label': 'negative', 'score': 0.9769197702407837}],
#  [{'label': 'negative', 'score': 0.9785641431808472}],
#  [{'label': 'negative', 'score': 0.9925618767738342}],
#  [{'label': 'negative', 'score': 0.9865682125091553}],
#  [{'label': 'negative', 'score': 0.9146256446838379}],
#  [{'label': 'negative', 'score': 0.9981892704963684}],
#  [{'label': 'negative', 'score': 0.9951915740966797}],
#  [{'label': 'negative', 'score': 0.9916371703147888}],
#  [{'label': 'positive', 'score': 0.5315084457397461}],
#  [{'label': 'negative', 'score': 0.7161531448364258}],
#  [{'label': 'negative', 'score': 0.8534213900566101}],
#  [{'label': 'negative', 'score': 0.9804199934005737}],
#  [{'label': 'negative', 'score': 0.9636833071708679}],
#  [{'label': 'negative', 'score': 0.9605682492256165}],
#  [{'label': 'negative', 'score': 0.9987260699272156}],
#  [{'label': 'negative', 'score': 0.9976925849914551}],
#  [{'label': 'negative', 'score': 0.9901905059814453}],
#  [{'label': 'negative', 'score': 0.9063878059387207}],
#  [{'label': 'negative', 'score': 0.8687132000923157}],
#  [{'label': 'negative', 'score': 0.8296292424201965}],
#  [{'label': 'negative', 'score': 0.9033525586128235}],
#  [{'label': 'negative', 'score': 0.9957362413406372}],
#  [{'label': 'negative', 'score': 0.9137099981307983}],
#  [{'label': 'negative', 'score': 0.9987486600875854}],
#  [{'label': 'negative', 'score': 0.9885281324386597}],
#  [{'label': 'negative', 'score': 0.9987998008728027}],
#  [{'label': 'positive', 'score': 0.7070437669754028}],
#  [{'label': 'negative', 'score': 0.501339316368103}],
#  [{'label': 'negative', 'score': 0.9965143799781799}],
#  [{'label': 'negative', 'score': 0.9932522177696228}],
#  [{'label': 'negative', 'score': 0.9911320805549622}],
#  [{'label': 'negative', 'score': 0.9942219853401184}],
#  [{'label': 'negative', 'score': 0.9911578297615051}],
#  [{'label': 'negative', 'score': 0.9981327652931213}],
#  [{'label': 'negative', 'score': 0.8294682502746582}],
#  [{'label': 'negative', 'score': 0.9960708618164062}],
#  [{'label': 'negative', 'score': 0.9956963062286377}],
#  [{'label': 'positive', 'score': 0.9887191653251648}],
#  [{'label': 'positive', 'score': 0.9053393006324768}],
#  [{'label': 'negative', 'score': 0.9948713779449463}],
#  [{'label': 'negative', 'score': 0.9944882988929749}],
#  [{'label': 'positive', 'score': 0.8883275985717773}],
#  [{'label': 'negative', 'score': 0.9919124841690063}],
#  [{'label': 'negative', 'score': 0.9717896580696106}],
#  [{'label': 'negative', 'score': 0.9974271655082703}],
#  [{'label': 'positive', 'score': 0.7914839386940002}],
#  [{'label': 'negative', 'score': 0.9974501729011536}],
#  [{'label': 'negative', 'score': 0.970949113368988}],
#  [{'label': 'negative', 'score': 0.9730435013771057}],
#  [{'label': 'negative', 'score': 0.998610258102417}],
#  [{'label': 'negative', 'score': 0.9976474642753601}],
#  [{'label': 'negative', 'score': 0.9974746108055115}],
#  [{'label': 'negative', 'score': 0.9939005374908447}],
#  [{'label': 'negative', 'score': 0.9928873181343079}],
#  [{'label': 'negative', 'score': 0.95322185754776}],
#  [{'label': 'negative', 'score': 0.995158851146698}],
#  [{'label': 'negative', 'score': 0.999406099319458}],
#  [{'label': 'negative', 'score': 0.9574443101882935}],
#  [{'label': 'negative', 'score': 0.9979627132415771}],
#  [{'label': 'negative', 'score': 0.9977973699569702}],
#  [{'label': 'negative', 'score': 0.9984263181686401}],
#  [{'label': 'negative', 'score': 0.9981575608253479}],
#  [{'label': 'negative', 'score': 0.9604240655899048}],
#  [{'label': 'negative', 'score': 0.9611256122589111}],
#  [{'label': 'negative', 'score': 0.9917886853218079}],
#  [{'label': 'negative', 'score': 0.9303070306777954}],
#  [{'label': 'negative', 'score': 0.9943033456802368}],
#  [{'label': 'positive', 'score': 0.8261610269546509}],
#  [{'label': 'negative', 'score': 0.9972612857818604}],
#  [{'label': 'negative', 'score': 0.921263575553894}],
#  [{'label': 'negative', 'score': 0.9978674650192261}],
#  [{'label': 'negative', 'score': 0.9754512906074524}],
#  [{'label': 'negative', 'score': 0.9993867874145508}],
#  [{'label': 'negative', 'score': 0.7880147695541382}],
#  [{'label': 'negative', 'score': 0.9989846348762512}],
#  [{'label': 'negative', 'score': 0.6269047856330872}],
#  [{'label': 'negative', 'score': 0.9268882870674133}],
#  [{'label': 'negative', 'score': 0.9974310994148254}],
#  [{'label': 'negative', 'score': 0.9858906269073486}],
#  [{'label': 'negative', 'score': 0.9991727471351624}],
#  [{'label': 'negative', 'score': 0.9935007691383362}],
#  [{'label': 'negative', 'score': 0.9940491914749146}],
#  [{'label': 'negative', 'score': 0.9190571904182434}],
#  [{'label': 'negative', 'score': 0.9984619617462158}],
#  [{'label': 'negative', 'score': 0.843180239200592}],
#  [{'label': 'negative', 'score': 0.9899391531944275}],
#  [{'label': 'positive', 'score': 0.9282991886138916}],
#  [{'label': 'negative', 'score': 0.9267634749412537}],
#  [{'label': 'negative', 'score': 0.7717116475105286}],
#  [{'label': 'negative', 'score': 0.5561584234237671}],
#  [{'label': 'negative', 'score': 0.8811917304992676}],
#  [{'label': 'negative', 'score': 0.9990260601043701}],
#  [{'label': 'negative', 'score': 0.9967713952064514}],
#  [{'label': 'positive', 'score': 0.8664562106132507}],
#  [{'label': 'negative', 'score': 0.9973980188369751}],
#  [{'label': 'positive', 'score': 0.8764126896858215}],
#  [{'label': 'negative', 'score': 0.9845259189605713}],
#  [{'label': 'negative', 'score': 0.9985002279281616}],
#  [{'label': 'negative', 'score': 0.973217248916626}],
#  [{'label': 'negative', 'score': 0.7484878897666931}],
#  [{'label': 'negative', 'score': 0.9589091539382935}],
#  [{'label': 'negative', 'score': 0.9080439209938049}],
#  [{'label': 'negative', 'score': 0.9916804432868958}],
#  [{'label': 'negative', 'score': 0.9927319884300232}],
#  [{'label': 'negative', 'score': 0.978460967540741}],
#  [{'label': 'negative', 'score': 0.9810927510261536}],
#  [{'label': 'negative', 'score': 0.9954804182052612}],
#  [{'label': 'negative', 'score': 0.9889286160469055}],
#  [{'label': 'negative', 'score': 0.9930399656295776}],
#  [{'label': 'negative', 'score': 0.9838922023773193}],
#  [{'label': 'negative', 'score': 0.9790522456169128}],
#  [{'label': 'negative', 'score': 0.825613260269165}],
#  [{'label': 'negative', 'score': 0.9765666723251343}],
#  [{'label': 'negative', 'score': 0.9792087078094482}],
#  [{'label': 'negative', 'score': 0.9924852252006531}],
#  [{'label': 'negative', 'score': 0.7825135588645935}],
#  [{'label': 'negative', 'score': 0.991195559501648}],
#  [{'label': 'negative', 'score': 0.943015456199646}],
#  [{'label': 'negative', 'score': 0.9989815354347229}],
#  [{'label': 'negative', 'score': 0.998783528804779}],
#  [{'label': 'negative', 'score': 0.5547388792037964}],
#  [{'label': 'negative', 'score': 0.9913924932479858}],
#  [{'label': 'negative', 'score': 0.8049414753913879}],
#  [{'label': 'positive', 'score': 0.5062242746353149}],
#  [{'label': 'negative', 'score': 0.9956583976745605}],
#  [{'label': 'negative', 'score': 0.9821565747261047}],
#  [{'label': 'negative', 'score': 0.9962467551231384}],
#  [{'label': 'negative', 'score': 0.9671311378479004}],
#  [{'label': 'negative', 'score': 0.9822319746017456}],
#  [{'label': 'negative', 'score': 0.9920022487640381}],
#  [{'label': 'negative', 'score': 0.9962162375450134}],
#  [{'label': 'negative', 'score': 0.9993312358856201}],
#  [{'label': 'negative', 'score': 0.9964380264282227}],
#  [{'label': 'negative', 'score': 0.998251736164093}],
#  [{'label': 'negative', 'score': 0.9916537404060364}],
#  [{'label': 'negative', 'score': 0.9866068363189697}],
#  [{'label': 'negative', 'score': 0.9925701022148132}],
#  [{'label': 'negative', 'score': 0.9951242804527283}],
#  [{'label': 'negative', 'score': 0.9790522456169128}],
#  [{'label': 'negative', 'score': 0.9991590976715088}],
#  [{'label': 'negative', 'score': 0.9970391988754272}],
#  [{'label': 'negative', 'score': 0.9445813894271851}],
#  [{'label': 'negative', 'score': 0.9970721006393433}],
#  [{'label': 'negative', 'score': 0.9975528120994568}],
#  [{'label': 'negative', 'score': 0.8367367386817932}],
#  [{'label': 'negative', 'score': 0.8223755359649658}],
#  [{'label': 'negative', 'score': 0.9026730060577393}],
#  [{'label': 'negative', 'score': 0.9770391583442688}],
#  [{'label': 'negative', 'score': 0.9134121537208557}],
#  [{'label': 'positive', 'score': 0.8387936949729919}],
#  [{'label': 'negative', 'score': 0.9442973732948303}],
#  [{'label': 'negative', 'score': 0.9985232949256897}],
#  [{'label': 'negative', 'score': 0.9195340871810913}],
#  [{'label': 'positive', 'score': 0.6717556118965149}],
#  [{'label': 'positive', 'score': 0.6623679995536804}],
#  [{'label': 'negative', 'score': 0.9461892247200012}],
#  [{'label': 'negative', 'score': 0.9988766312599182}],
#  [{'label': 'negative', 'score': 0.9985814094543457}],
#  [{'label': 'negative', 'score': 0.996137797832489}],
#  [{'label': 'positive', 'score': 0.9724974036216736}],
#  [{'label': 'negative', 'score': 0.992733359336853}],
#  [{'label': 'negative', 'score': 0.9952589869499207}],
#  [{'label': 'negative', 'score': 0.8518384099006653}],
#  [{'label': 'positive', 'score': 0.9998667240142822}],
#  [{'label': 'negative', 'score': 0.9897488951683044}],
#  [{'label': 'negative', 'score': 0.9967472553253174}],
#  [{'label': 'negative', 'score': 0.9994857311248779}],
#  [{'label': 'negative', 'score': 0.9773072004318237}],
#  [{'label': 'negative', 'score': 0.9574661254882812}],
#  [{'label': 'negative', 'score': 0.9884097576141357}],
#  [{'label': 'negative', 'score': 0.9931720495223999}],
#  [{'label': 'negative', 'score': 0.9834885001182556}],
#  [{'label': 'negative', 'score': 0.875296413898468}],
#  [{'label': 'positive', 'score': 0.6582790017127991}],
#  [{'label': 'negative', 'score': 0.9979627132415771}],
#  [{'label': 'negative', 'score': 0.9766489863395691}],
#  [{'label': 'positive', 'score': 0.959798276424408}],
#  [{'label': 'negative', 'score': 0.8885547518730164}],
#  [{'label': 'negative', 'score': 0.8609216809272766}],
#  [{'label': 'negative', 'score': 0.9858479499816895}],
#  [{'label': 'negative', 'score': 0.9703585505485535}],
#  [{'label': 'negative', 'score': 0.9976650476455688}],
#  [{'label': 'negative', 'score': 0.9987738728523254}],
#  [{'label': 'positive', 'score': 0.979534387588501}],
#  [{'label': 'negative', 'score': 0.9629548788070679}],
#  [{'label': 'positive', 'score': 0.5531376600265503}],
#  [{'label': 'negative', 'score': 0.6969297528266907}],
#  [{'label': 'negative', 'score': 0.9909949898719788}],
#  [{'label': 'negative', 'score': 0.9991311430931091}],
#  [{'label': 'negative', 'score': 0.7640471458435059}],
#  [{'label': 'negative', 'score': 0.9962459206581116}],
#  [{'label': 'positive', 'score': 0.571578323841095}],
#  [{'label': 'positive', 'score': 0.9062003493309021}],
#  [{'label': 'positive', 'score': 0.8291532397270203}],
#  [{'label': 'negative', 'score': 0.8180403113365173}],
#  [{'label': 'negative', 'score': 0.9904820919036865}],
#  [{'label': 'negative', 'score': 0.9594495892524719}],
#  [{'label': 'negative', 'score': 0.9955814480781555}],
#  [{'label': 'negative', 'score': 0.9938969016075134}],
#  [{'label': 'negative', 'score': 0.9980758428573608}],
#  [{'label': 'negative', 'score': 0.9960097074508667}],
#  [{'label': 'negative', 'score': 0.5322390794754028}],
#  [{'label': 'negative', 'score': 0.9898872971534729}],
#  [{'label': 'negative', 'score': 0.9926605224609375}],
#  [{'label': 'negative', 'score': 0.9983770847320557}],
#  [{'label': 'positive', 'score': 0.9847812652587891}],
#  [{'label': 'negative', 'score': 0.8489242792129517}],
#  [{'label': 'positive', 'score': 0.8475418090820312}],
#  [{'label': 'negative', 'score': 0.9783373475074768}],
#  [{'label': 'negative', 'score': 0.9966452717781067}],
#  [{'label': 'negative', 'score': 0.9737083911895752}],
#  [{'label': 'negative', 'score': 0.9923593401908875}],
#  [{'label': 'positive', 'score': 0.9362404942512512}],
#  [{'label': 'positive', 'score': 0.9809150695800781}],
#  [{'label': 'negative', 'score': 0.9919872283935547}],
#  [{'label': 'negative', 'score': 0.9158604145050049}],
#  [{'label': 'negative', 'score': 0.9670125842094421}],
#  [{'label': 'negative', 'score': 0.9356316924095154}],
#  [{'label': 'negative', 'score': 0.999026894569397}],
#  [{'label': 'negative', 'score': 0.965453028678894}],
#  [{'label': 'negative', 'score': 0.8743292689323425}],
#  [{'label': 'negative', 'score': 0.8412541747093201}],
#  [{'label': 'negative', 'score': 0.9194267392158508}],
#  [{'label': 'negative', 'score': 0.9585773348808289}],
#  [{'label': 'negative', 'score': 0.9434666037559509}],
#  [{'label': 'negative', 'score': 0.9956222176551819}],
#  [{'label': 'positive', 'score': 0.7813523411750793}],
#  [{'label': 'positive', 'score': 0.9491731524467468}],
#  [{'label': 'negative', 'score': 0.9630499482154846}],
#  [{'label': 'negative', 'score': 0.9907228350639343}],
#  [{'label': 'negative', 'score': 0.9981949925422668}],
#  [{'label': 'negative', 'score': 0.990107536315918}],
#  [{'label': 'negative', 'score': 0.9898092746734619}],
#  [{'label': 'negative', 'score': 0.9950090646743774}],
#  [{'label': 'negative', 'score': 0.9981808662414551}],
#  [{'label': 'negative', 'score': 0.9742214679718018}],
#  [{'label': 'negative', 'score': 0.9716635942459106}],
#  [{'label': 'negative', 'score': 0.9991732239723206}],
#  [{'label': 'positive', 'score': 0.9116528034210205}],
#  [{'label': 'negative', 'score': 0.9684646129608154}],
#  [{'label': 'negative', 'score': 0.9788837432861328}],
#  [{'label': 'negative', 'score': 0.979775071144104}],
#  [{'label': 'negative', 'score': 0.988911509513855}],
#  [{'label': 'negative', 'score': 0.8314030170440674}],
#  [{'label': 'negative', 'score': 0.9336764812469482}],
#  [{'label': 'negative', 'score': 0.9874206185340881}],
#  [{'label': 'negative', 'score': 0.8639749884605408}],
#  [{'label': 'negative', 'score': 0.9820575714111328}],
#  [{'label': 'negative', 'score': 0.9495928287506104}],
#  [{'label': 'negative', 'score': 0.996830403804779}],
#  [{'label': 'negative', 'score': 0.8529155850410461}],
#  [{'label': 'positive', 'score': 0.7461805939674377}],
#  [{'label': 'negative', 'score': 0.9084981679916382}],
#  [{'label': 'negative', 'score': 0.9976410865783691}],
#  [{'label': 'negative', 'score': 0.9978718757629395}],
#  [{'label': 'negative', 'score': 0.8360909819602966}],
#  [{'label': 'negative', 'score': 0.9988430738449097}],
#  [{'label': 'negative', 'score': 0.9989257454872131}],
#  [{'label': 'positive', 'score': 0.5302099585533142}],
#  [{'label': 'positive', 'score': 0.8310295343399048}],
#  [{'label': 'negative', 'score': 0.8827353119850159}],
#  [{'label': 'negative', 'score': 0.9937445521354675}],
#  [{'label': 'negative', 'score': 0.8463662266731262}],
#  [{'label': 'negative', 'score': 0.9959427714347839}],
#  [{'label': 'negative', 'score': 0.9332314729690552}],
#  [{'label': 'negative', 'score': 0.9933291673660278}],
#  [{'label': 'negative', 'score': 0.9415217041969299}],
#  [{'label': 'negative', 'score': 0.9973539113998413}],
#  [{'label': 'negative', 'score': 0.6899992823600769}],
#  [{'label': 'negative', 'score': 0.8211507201194763}],
#  [{'label': 'positive', 'score': 0.5503879189491272}],
#  [{'label': 'positive', 'score': 0.8820247054100037}],
#  [{'label': 'negative', 'score': 0.9391554594039917}],
#  [{'label': 'negative', 'score': 0.9937537312507629}],
#  [{'label': 'positive', 'score': 0.9212939739227295}],
#  [{'label': 'negative', 'score': 0.8253090381622314}],
#  [{'label': 'negative', 'score': 0.9693153500556946}],
#  [{'label': 'positive', 'score': 0.937488317489624}],
#  [{'label': 'negative', 'score': 0.8707329630851746}],
#  [{'label': 'negative', 'score': 0.931441605091095}],
#  [{'label': 'negative', 'score': 0.8422425985336304}],
#  [{'label': 'negative', 'score': 0.8962789177894592}],
#  [{'label': 'negative', 'score': 0.9967220425605774}],
#  [{'label': 'negative', 'score': 0.9924100637435913}],
#  [{'label': 'positive', 'score': 0.6246083974838257}],
#  [{'label': 'negative', 'score': 0.5186271071434021}],
#  [{'label': 'negative', 'score': 0.9882137775421143}],
#  [{'label': 'negative', 'score': 0.9188898801803589}],
#  [{'label': 'negative', 'score': 0.7935292720794678}],
#  [{'label': 'negative', 'score': 0.9785929322242737}],
#  [{'label': 'negative', 'score': 0.999045193195343}],
#  [{'label': 'negative', 'score': 0.983977735042572}],
#  [{'label': 'negative', 'score': 0.8761831521987915}],
#  [{'label': 'negative', 'score': 0.9950034022331238}],
#  [{'label': 'negative', 'score': 0.997369647026062}],
#  [{'label': 'negative', 'score': 0.9980617165565491}],
#  [{'label': 'negative', 'score': 0.8448792099952698}],
#  [{'label': 'negative', 'score': 0.956318736076355}],
#  [{'label': 'negative', 'score': 0.9978747367858887}],
#  [{'label': 'negative', 'score': 0.9983835220336914}],
#  [{'label': 'negative', 'score': 0.9365473985671997}],
#  [{'label': 'negative', 'score': 0.997178316116333}],
#  [{'label': 'negative', 'score': 0.9034213423728943}],
#  [{'label': 'positive', 'score': 0.7672891616821289}],
#  [{'label': 'negative', 'score': 0.9883111119270325}],
#  [{'label': 'negative', 'score': 0.9830407500267029}],
#  [{'label': 'negative', 'score': 0.8903957605361938}],
#  [{'label': 'negative', 'score': 0.9806743264198303}],
#  [{'label': 'negative', 'score': 0.9629517793655396}],
#  [{'label': 'negative', 'score': 0.7880016565322876}],
#  [{'label': 'negative', 'score': 0.9938740134239197}],
#  [{'label': 'negative', 'score': 0.9932168126106262}],
#  [{'label': 'negative', 'score': 0.6966701745986938}],
#  [{'label': 'negative', 'score': 0.9339121580123901}],
#  [{'label': 'negative', 'score': 0.9982613921165466}],
#  [{'label': 'negative', 'score': 0.5981900691986084}],
#  [{'label': 'negative', 'score': 0.9862567782402039}],
#  [{'label': 'negative', 'score': 0.9381749629974365}],
#  [{'label': 'negative', 'score': 0.9972342848777771}],
#  [{'label': 'negative', 'score': 0.9988707900047302}],
#  [{'label': 'negative', 'score': 0.7753536105155945}],
#  [{'label': 'positive', 'score': 0.8417218327522278}],
#  [{'label': 'negative', 'score': 0.9982226490974426}],
#  [{'label': 'negative', 'score': 0.9942554831504822}],
#  [{'label': 'negative', 'score': 0.9335801601409912}],
#  [{'label': 'negative', 'score': 0.9207236170768738}],
#  [{'label': 'negative', 'score': 0.989216685295105}],
#  [{'label': 'negative', 'score': 0.9950999617576599}],
#  [{'label': 'negative', 'score': 0.5814087390899658}],
#  [{'label': 'negative', 'score': 0.996813952922821}],
#  [{'label': 'positive', 'score': 0.7506885528564453}],
#  [{'label': 'negative', 'score': 0.8828500509262085}],
#  [{'label': 'negative', 'score': 0.9942415952682495}],
#  [{'label': 'negative', 'score': 0.9954160451889038}],
#  [{'label': 'positive', 'score': 0.6793032288551331}],
#  [{'label': 'negative', 'score': 0.6358031034469604}],
#  [{'label': 'negative', 'score': 0.6040100455284119}],
#  [{'label': 'negative', 'score': 0.9824054837226868}],
#  [{'label': 'positive', 'score': 0.5330803394317627}],
#  [{'label': 'negative', 'score': 0.9936530590057373}],
#  [{'label': 'negative', 'score': 0.9622414112091064}],
#  [{'label': 'negative', 'score': 0.9780608415603638}],
#  [{'label': 'negative', 'score': 0.9943244457244873}],
#  [{'label': 'negative', 'score': 0.6909248232841492}],
#  [{'label': 'negative', 'score': 0.9447447657585144}],
#  [{'label': 'negative', 'score': 0.984794557094574}],
#  [{'label': 'negative', 'score': 0.997995138168335}],
#  [{'label': 'negative', 'score': 0.9889113903045654}],
#  [{'label': 'negative', 'score': 0.9807190895080566}],
#  [{'label': 'negative', 'score': 0.9933773875236511}],
#  [{'label': 'negative', 'score': 0.9969480633735657}],
#  [{'label': 'negative', 'score': 0.880818784236908}],
#  [{'label': 'negative', 'score': 0.9804607033729553}],
#  [{'label': 'positive', 'score': 0.956058919429779}],
#  [{'label': 'negative', 'score': 0.926039457321167}],
#  [{'label': 'negative', 'score': 0.5646578669548035}],
#  [{'label': 'negative', 'score': 0.9830097556114197}],
#  [{'label': 'negative', 'score': 0.9279612302780151}],
#  [{'label': 'negative', 'score': 0.6263360977172852}],
#  [{'label': 'negative', 'score': 0.9901048541069031}],
#  [{'label': 'negative', 'score': 0.9984038472175598}],
#  [{'label': 'negative', 'score': 0.8011940121650696}],
#  [{'label': 'positive', 'score': 0.9225862622261047}],
#  [{'label': 'negative', 'score': 0.8499900698661804}],
#  [{'label': 'negative', 'score': 0.9937915205955505}],
#  [{'label': 'negative', 'score': 0.9726915955543518}],
#  [{'label': 'negative', 'score': 0.996812641620636}],
#  [{'label': 'negative', 'score': 0.9979789853096008}],
#  [{'label': 'negative', 'score': 0.9823035597801208}],
#  [{'label': 'negative', 'score': 0.9979121088981628}],
#  [{'label': 'negative', 'score': 0.9969406127929688}],
#  [{'label': 'negative', 'score': 0.979625403881073}],
#  [{'label': 'negative', 'score': 0.9994708895683289}],
#  [{'label': 'negative', 'score': 0.9831618070602417}],
#  [{'label': 'negative', 'score': 0.9682435989379883}],
#  [{'label': 'negative', 'score': 0.9438782930374146}],
#  [{'label': 'negative', 'score': 0.9983987212181091}],
#  [{'label': 'negative', 'score': 0.9638611674308777}],
#  [{'label': 'negative', 'score': 0.8160704970359802}],
#  [{'label': 'negative', 'score': 0.9556069374084473}],
#  [{'label': 'negative', 'score': 0.9921557307243347}],
#  [{'label': 'negative', 'score': 0.9731529951095581}],
#  [{'label': 'negative', 'score': 0.9031139016151428}],
#  [{'label': 'negative', 'score': 0.9925423860549927}],
#  [{'label': 'negative', 'score': 0.6370400190353394}],
#  [{'label': 'negative', 'score': 0.9397452473640442}],
#  [{'label': 'negative', 'score': 0.9092510342597961}],
#  [{'label': 'negative', 'score': 0.9957678318023682}],
#  [{'label': 'negative', 'score': 0.9990987777709961}],
#  [{'label': 'negative', 'score': 0.9728526473045349}],
#  [{'label': 'negative', 'score': 0.9890668392181396}],
#  [{'label': 'negative', 'score': 0.9717063903808594}],
#  [{'label': 'positive', 'score': 0.9327605962753296}],
#  [{'label': 'negative', 'score': 0.9879876375198364}],
#  [{'label': 'negative', 'score': 0.997538685798645}],
#  [{'label': 'negative', 'score': 0.9873145818710327}],
#  [{'label': 'negative', 'score': 0.9982074499130249}],
#  [{'label': 'negative', 'score': 0.9983717799186707}],
#  [{'label': 'negative', 'score': 0.9987288117408752}],
#  [{'label': 'negative', 'score': 0.9886835217475891}],
#  [{'label': 'negative', 'score': 0.9993422627449036}],
#  [{'label': 'negative', 'score': 0.9937605261802673}],
#  [{'label': 'negative', 'score': 0.9937864542007446}],
#  [{'label': 'negative', 'score': 0.9534763693809509}],
#  [{'label': 'negative', 'score': 0.990298867225647}],
#  [{'label': 'negative', 'score': 0.99354088306427}],
#  [{'label': 'negative', 'score': 0.998180627822876}],
#  [{'label': 'positive', 'score': 0.5146447420120239}],
#  [{'label': 'negative', 'score': 0.9267144203186035}],
#  [{'label': 'negative', 'score': 0.9834686517715454}],
#  [{'label': 'positive', 'score': 0.6002402901649475}],
#  [{'label': 'negative', 'score': 0.9986925721168518}],
#  [{'label': 'negative', 'score': 0.981033444404602}],
#  [{'label': 'negative', 'score': 0.5559458136558533}],
#  [{'label': 'negative', 'score': 0.9747219085693359}],
#  [{'label': 'negative', 'score': 0.9952207207679749}],
#  [{'label': 'positive', 'score': 0.9671823978424072}],
#  [{'label': 'negative', 'score': 0.9937583208084106}],
#  [{'label': 'negative', 'score': 0.8226376175880432}],
#  [{'label': 'negative', 'score': 0.6161265969276428}],
#  [{'label': 'negative', 'score': 0.9895135164260864}],
#  [{'label': 'negative', 'score': 0.9979714751243591}],
#  [{'label': 'negative', 'score': 0.9964284300804138}],
#  [{'label': 'negative', 'score': 0.9941177368164062}],
#  [{'label': 'negative', 'score': 0.9959086179733276}],
#  [{'label': 'negative', 'score': 0.9928499460220337}],
#  [{'label': 'negative', 'score': 0.9984459280967712}],
#  [{'label': 'negative', 'score': 0.699604332447052}],
#  [{'label': 'negative', 'score': 0.9830994606018066}],
#  [{'label': 'negative', 'score': 0.9031139016151428}],
#  [{'label': 'negative', 'score': 0.9925423860549927}],
#  [{'label': 'negative', 'score': 0.8068286776542664}],
#  [{'label': 'negative', 'score': 0.8011940121650696}],
#  [{'label': 'negative', 'score': 0.9985992312431335}],
#  [{'label': 'negative', 'score': 0.9716576337814331}],
#  [{'label': 'negative', 'score': 0.9975676536560059}],
#  [{'label': 'negative', 'score': 0.9967712759971619}],
#  [{'label': 'positive', 'score': 0.9998703002929688}],
#  [{'label': 'negative', 'score': 0.9886491298675537}],
#  [{'label': 'negative', 'score': 0.7049092054367065}],
#  [{'label': 'negative', 'score': 0.9865949153900146}],
#  [{'label': 'negative', 'score': 0.8836738467216492}],
#  [{'label': 'negative', 'score': 0.9957830905914307}],
#  [{'label': 'negative', 'score': 0.9993283748626709}],
#  [{'label': 'negative', 'score': 0.9921964406967163}],
#  [{'label': 'negative', 'score': 0.9928069114685059}],
#  [{'label': 'negative', 'score': 0.9948904514312744}],
#  [{'label': 'positive', 'score': 0.9366846680641174}],
#  [{'label': 'negative', 'score': 0.9963160157203674}],
#  [{'label': 'negative', 'score': 0.7949568629264832}],
#  [{'label': 'positive', 'score': 0.6770564317703247}],
#  [{'label': 'negative', 'score': 0.9927160143852234}],
#  [{'label': 'negative', 'score': 0.5877940058708191}],
#  [{'label': 'positive', 'score': 0.9019187092781067}],
#  [{'label': 'negative', 'score': 0.9391030073165894}],
#  [{'label': 'negative', 'score': 0.9956037998199463}],
#  [{'label': 'negative', 'score': 0.9925998449325562}],
#  [{'label': 'negative', 'score': 0.9758850932121277}],
#  [{'label': 'negative', 'score': 0.5054585933685303}],
#  [{'label': 'negative', 'score': 0.9822940826416016}],
#  [{'label': 'negative', 'score': 0.9965271353721619}],
#  [{'label': 'negative', 'score': 0.9453782439231873}],
#  [{'label': 'positive', 'score': 0.6377613544464111}],
#  [{'label': 'negative', 'score': 0.8760451674461365}],
#  [{'label': 'negative', 'score': 0.9849958419799805}],
#  [{'label': 'negative', 'score': 0.9925423860549927}],
#  [{'label': 'negative', 'score': 0.9248583912849426}],
#  [{'label': 'negative', 'score': 0.9154515862464905}],
#  [{'label': 'negative', 'score': 0.8890605568885803}],
#  [{'label': 'negative', 'score': 0.8002832531929016}],
#  [{'label': 'negative', 'score': 0.9942492246627808}],
#  [{'label': 'negative', 'score': 0.9622899889945984}],
#  [{'label': 'negative', 'score': 0.9713626503944397}],
#  [{'label': 'negative', 'score': 0.9842733144760132}],
#  [{'label': 'negative', 'score': 0.9608564376831055}],
#  [{'label': 'negative', 'score': 0.8848496079444885}],
#  [{'label': 'negative', 'score': 0.9639712572097778}],
#  [{'label': 'negative', 'score': 0.9975327253341675}],
#  [{'label': 'negative', 'score': 0.9912993311882019}],
#  [{'label': 'negative', 'score': 0.998465895652771}],
#  [{'label': 'negative', 'score': 0.9988724589347839}],
#  [{'label': 'negative', 'score': 0.9202046990394592}],
#  [{'label': 'negative', 'score': 0.951524555683136}],
#  [{'label': 'negative', 'score': 0.9964906573295593}],
#  [{'label': 'positive', 'score': 0.7751255035400391}],
#  [{'label': 'negative', 'score': 0.8903181552886963}],
#  [{'label': 'negative', 'score': 0.7332519292831421}],
#  [{'label': 'negative', 'score': 0.9488940834999084}],
#  [{'label': 'negative', 'score': 0.9936198592185974}],
#  [{'label': 'negative', 'score': 0.9725613594055176}],
#  [{'label': 'negative', 'score': 0.9791178703308105}],
#  [{'label': 'negative', 'score': 0.9944630265235901}],
#  [{'label': 'positive', 'score': 0.6923298239707947}],
#  [{'label': 'positive', 'score': 0.5670970678329468}],
#  [{'label': 'negative', 'score': 0.9976213574409485}],
#  [{'label': 'negative', 'score': 0.9726638197898865}],
#  [{'label': 'negative', 'score': 0.9500149488449097}],
#  [{'label': 'negative', 'score': 0.8859920501708984}],
#  [{'label': 'positive', 'score': 0.967297375202179}],
#  [{'label': 'negative', 'score': 0.9812545776367188}],
#  [{'label': 'negative', 'score': 0.987427830696106}],
#  [{'label': 'negative', 'score': 0.9952646493911743}],
#  [{'label': 'negative', 'score': 0.9783172607421875}],
#  [{'label': 'negative', 'score': 0.9846163988113403}],
#  [{'label': 'negative', 'score': 0.966950535774231}],
#  [{'label': 'negative', 'score': 0.9969820380210876}],
#  [{'label': 'negative', 'score': 0.9968666434288025}],
#  [{'label': 'negative', 'score': 0.9951576590538025}],
#  [{'label': 'negative', 'score': 0.9435372948646545}],
#  [{'label': 'negative', 'score': 0.9949870109558105}],
#  [{'label': 'negative', 'score': 0.9976735711097717}],
#  [{'label': 'negative', 'score': 0.938428521156311}],
#  [{'label': 'negative', 'score': 0.9970581531524658}],
#  [{'label': 'positive', 'score': 0.9898034334182739}],
#  [{'label': 'negative', 'score': 0.9969478249549866}],
#  [{'label': 'negative', 'score': 0.9665486216545105}],
#  [{'label': 'negative', 'score': 0.9909918308258057}],
#  [{'label': 'negative', 'score': 0.9921093583106995}],
#  [{'label': 'negative', 'score': 0.9321977496147156}],
#  [{'label': 'negative', 'score': 0.9877097606658936}],
#  [{'label': 'negative', 'score': 0.997020423412323}],
#  [{'label': 'negative', 'score': 0.8916881680488586}],
#  [{'label': 'negative', 'score': 0.997960090637207}],
#  [{'label': 'negative', 'score': 0.9945551156997681}],
#  [{'label': 'positive', 'score': 0.5665390491485596}],
#  [{'label': 'negative', 'score': 0.8620985150337219}],
#  [{'label': 'negative', 'score': 0.8323836922645569}],
#  [{'label': 'negative', 'score': 0.9414114952087402}],
#  [{'label': 'negative', 'score': 0.9984991550445557}],
#  [{'label': 'positive', 'score': 0.6846559643745422}],
#  [{'label': 'negative', 'score': 0.9951131939888}],
#  [{'label': 'negative', 'score': 0.9975908994674683}],
#  [{'label': 'negative', 'score': 0.7457011342048645}],
#  [{'label': 'negative', 'score': 0.8582277297973633}],
#  [{'label': 'negative', 'score': 0.9967647790908813}],
#  [{'label': 'negative', 'score': 0.9870060682296753}],
#  [{'label': 'negative', 'score': 0.9507828950881958}],
#  [{'label': 'negative', 'score': 0.9199806451797485}],
#  [{'label': 'negative', 'score': 0.8232871890068054}],
#  [{'label': 'negative', 'score': 0.9948531985282898}],
#  [{'label': 'negative', 'score': 0.9903472661972046}],
#  [{'label': 'negative', 'score': 0.9688160419464111}],
#  [{'label': 'negative', 'score': 0.995952844619751}],
#  [{'label': 'negative', 'score': 0.9847707152366638}],
#  [{'label': 'negative', 'score': 0.9950546026229858}],
#  [{'label': 'negative', 'score': 0.9986063838005066}],
#  [{'label': 'negative', 'score': 0.9920601844787598}],
#  [{'label': 'negative', 'score': 0.9959254264831543}],
#  [{'label': 'negative', 'score': 0.9392812252044678}],
#  [{'label': 'negative', 'score': 0.9904361367225647}],
#  [{'label': 'negative', 'score': 0.9984238147735596}],
#  [{'label': 'negative', 'score': 0.9780805706977844}],
#  [{'label': 'negative', 'score': 0.9851240515708923}],
#  [{'label': 'negative', 'score': 0.9966458678245544}],
#  [{'label': 'negative', 'score': 0.9897217154502869}],
#  [{'label': 'negative', 'score': 0.9960305094718933}],
#  [{'label': 'negative', 'score': 0.966570258140564}],
#  [{'label': 'negative', 'score': 0.9925423860549927}],
#  [{'label': 'negative', 'score': 0.9992604851722717}],
#  [{'label': 'negative', 'score': 0.9696102142333984}],
#  [{'label': 'negative', 'score': 0.8252241611480713}],
#  [{'label': 'negative', 'score': 0.996301531791687}],
#  [{'label': 'negative', 'score': 0.9902745485305786}],
#  [{'label': 'negative', 'score': 0.9897818565368652}],
#  [{'label': 'negative', 'score': 0.9960808157920837}],
#  [{'label': 'negative', 'score': 0.9979668259620667}],
#  [{'label': 'negative', 'score': 0.9983285069465637}],
#  [{'label': 'negative', 'score': 0.9934632778167725}],
#  [{'label': 'negative', 'score': 0.9870517253875732}],
#  [{'label': 'negative', 'score': 0.9966854453086853}],
#  [{'label': 'negative', 'score': 0.997271716594696}],
#  [{'label': 'negative', 'score': 0.9898086190223694}],
#  [{'label': 'negative', 'score': 0.743977963924408}],
#  [{'label': 'negative', 'score': 0.7618609666824341}],
#  [{'label': 'positive', 'score': 0.9677717685699463}],
#  [{'label': 'positive', 'score': 0.5969401001930237}],
#  [{'label': 'negative', 'score': 0.8324908018112183}],
#  [{'label': 'positive', 'score': 0.7327039241790771}],
#  [{'label': 'negative', 'score': 0.9961820244789124}],
#  [{'label': 'negative', 'score': 0.9617984294891357}],
#  [{'label': 'negative', 'score': 0.9991682767868042}],
#  [{'label': 'negative', 'score': 0.9965323209762573}],
#  [{'label': 'negative', 'score': 0.993174135684967}],
#  [{'label': 'negative', 'score': 0.9644438028335571}],
#  [{'label': 'negative', 'score': 0.9070226550102234}],
#  [{'label': 'positive', 'score': 0.5355367660522461}],
#  [{'label': 'negative', 'score': 0.9578346014022827}],
#  [{'label': 'negative', 'score': 0.8033565282821655}],
#  [{'label': 'positive', 'score': 0.523820698261261}],
#  [{'label': 'negative', 'score': 0.9946710467338562}],
#  [{'label': 'negative', 'score': 0.9898048639297485}],
#  [{'label': 'negative', 'score': 0.5236506462097168}],
#  [{'label': 'negative', 'score': 0.9980231523513794}],
#  [{'label': 'negative', 'score': 0.7926725745201111}],
#  [{'label': 'negative', 'score': 0.9925423860549927}],
#  [{'label': 'negative', 'score': 0.9642856121063232}],
#  [{'label': 'negative', 'score': 0.979465663433075}],
#  [{'label': 'negative', 'score': 0.9981985688209534}],
#  [{'label': 'negative', 'score': 0.872989296913147}],
#  [{'label': 'negative', 'score': 0.8070509433746338}],
#  [{'label': 'positive', 'score': 0.8947502374649048}],
#  [{'label': 'negative', 'score': 0.9963868856430054}],
#  [{'label': 'negative', 'score': 0.8229838609695435}],
#  [{'label': 'negative', 'score': 0.9990828037261963}],
#  [{'label': 'negative', 'score': 0.9415026903152466}],
#  [{'label': 'negative', 'score': 0.9043005108833313}],
#  [{'label': 'negative', 'score': 0.993117094039917}],
#  [{'label': 'negative', 'score': 0.9786813855171204}],
#  [{'label': 'negative', 'score': 0.861107587814331}],
#  [{'label': 'negative', 'score': 0.9588430523872375}],
#  [{'label': 'negative', 'score': 0.9499505758285522}],
#  [{'label': 'negative', 'score': 0.9976239800453186}],
#  [{'label': 'positive', 'score': 0.7674810886383057}],
#  [{'label': 'negative', 'score': 0.9978419542312622}],
#  [{'label': 'negative', 'score': 0.9919151067733765}],
#  [{'label': 'negative', 'score': 0.9742120504379272}],
#  [{'label': 'negative', 'score': 0.9989558458328247}],
#  [{'label': 'negative', 'score': 0.9633393883705139}],
#  [{'label': 'negative', 'score': 0.9966621398925781}],
#  [{'label': 'negative', 'score': 0.9968394041061401}],
#  [{'label': 'positive', 'score': 0.5928546190261841}],
#  [{'label': 'negative', 'score': 0.8009835481643677}],
#  [{'label': 'negative', 'score': 0.9973805546760559}],
#  [{'label': 'negative', 'score': 0.9392227530479431}],
#  [{'label': 'negative', 'score': 0.9986623525619507}],
#  [{'label': 'negative', 'score': 0.7685837745666504}],
#  [{'label': 'negative', 'score': 0.9439496994018555}],
#  [{'label': 'negative', 'score': 0.9981299042701721}],
#  [{'label': 'negative', 'score': 0.9966795444488525}],
#  [{'label': 'negative', 'score': 0.9429113268852234}],
#  [{'label': 'negative', 'score': 0.9892375469207764}],
#  [{'label': 'negative', 'score': 0.9983018636703491}],
#  [{'label': 'negative', 'score': 0.9832558631896973}],
#  [{'label': 'negative', 'score': 0.9971587657928467}],
#  [{'label': 'negative', 'score': 0.9976401329040527}],
#  [{'label': 'negative', 'score': 0.9975772500038147}],
#  [{'label': 'negative', 'score': 0.9991088509559631}],
#  [{'label': 'negative', 'score': 0.9895963072776794}],
#  [{'label': 'negative', 'score': 0.9984216690063477}],
#  [{'label': 'positive', 'score': 0.5613899230957031}],
#  [{'label': 'negative', 'score': 0.8245533108711243}],
#  [{'label': 'negative', 'score': 0.9812560677528381}],
#  [{'label': 'negative', 'score': 0.9630910754203796}],
#  [{'label': 'negative', 'score': 0.6919868588447571}],
#  [{'label': 'negative', 'score': 0.9984723925590515}],
#  [{'label': 'positive', 'score': 0.6580584049224854}],
#  [{'label': 'negative', 'score': 0.9922382235527039}],
#  [{'label': 'negative', 'score': 0.9968157410621643}],
#  [{'label': 'negative', 'score': 0.9633442163467407}],
#  [{'label': 'positive', 'score': 0.822551965713501}],
#  [{'label': 'negative', 'score': 0.7693599462509155}],
#  [{'label': 'negative', 'score': 0.9843711256980896}],
#  [{'label': 'negative', 'score': 0.9028286337852478}],
#  [{'label': 'negative', 'score': 0.9981923699378967}],
#  [{'label': 'negative', 'score': 0.9585094451904297}],
#  [{'label': 'negative', 'score': 0.998426079750061}],
#  [{'label': 'negative', 'score': 0.9890190958976746}],
#  [{'label': 'negative', 'score': 0.9805912375450134}],
#  [{'label': 'negative', 'score': 0.9345946907997131}],
#  [{'label': 'negative', 'score': 0.9698909521102905}],
#  [{'label': 'negative', 'score': 0.9827661514282227}],
#  [{'label': 'negative', 'score': 0.9508373141288757}],
#  [{'label': 'negative', 'score': 0.9585276246070862}],
#  [{'label': 'negative', 'score': 0.8841840624809265}],
#  [{'label': 'negative', 'score': 0.9983959794044495}],
#  [{'label': 'positive', 'score': 0.6104259490966797}],
#  [{'label': 'negative', 'score': 0.985524594783783}],
#  [{'label': 'negative', 'score': 0.9876558780670166}],
#  [{'label': 'negative', 'score': 0.7310861349105835}],
#  [{'label': 'negative', 'score': 0.9205371141433716}],
#  [{'label': 'positive', 'score': 0.9973600506782532}],
#  [{'label': 'negative', 'score': 0.9974865913391113}],
#  [{'label': 'negative', 'score': 0.9945257902145386}],
#  [{'label': 'negative', 'score': 0.9970929622650146}],
#  [{'label': 'negative', 'score': 0.9812433123588562}],
#  [{'label': 'negative', 'score': 0.9845632910728455}],
#  [{'label': 'positive', 'score': 0.6601848006248474}],
#  [{'label': 'negative', 'score': 0.9895102977752686}],
#  [{'label': 'negative', 'score': 0.9775657653808594}],
#  [{'label': 'negative', 'score': 0.9973421692848206}],
#  [{'label': 'negative', 'score': 0.9801012277603149}],
#  [{'label': 'negative', 'score': 0.9831600785255432}],
#  [{'label': 'positive', 'score': 0.9939090013504028}],
#  [{'label': 'negative', 'score': 0.9972367286682129}],
#  [{'label': 'negative', 'score': 0.8257947564125061}],
#  [{'label': 'negative', 'score': 0.999056875705719}],
#  [{'label': 'negative', 'score': 0.6925212144851685}],
#  [{'label': 'negative', 'score': 0.9419973492622375}],
#  [{'label': 'negative', 'score': 0.9543727040290833}],
#  [{'label': 'negative', 'score': 0.9906491637229919}],
#  [{'label': 'negative', 'score': 0.9973813891410828}],
#  [{'label': 'negative', 'score': 0.9320420622825623}],
#  [{'label': 'negative', 'score': 0.8491771817207336}],
#  [{'label': 'positive', 'score': 0.6123847365379333}],
#  [{'label': 'negative', 'score': 0.955828070640564}],
#  [{'label': 'negative', 'score': 0.9850584268569946}],
#  [{'label': 'negative', 'score': 0.7236189842224121}],
#  [{'label': 'negative', 'score': 0.8550129532814026}],
#  [{'label': 'negative', 'score': 0.9987860321998596}],
#  [{'label': 'negative', 'score': 0.5521306395530701}],
#  [{'label': 'negative', 'score': 0.9608170390129089}],
#  [{'label': 'negative', 'score': 0.9932947754859924}],
#  [{'label': 'negative', 'score': 0.9145321249961853}],
#  [{'label': 'negative', 'score': 0.898838996887207}],
#  [{'label': 'negative', 'score': 0.9189435839653015}],
#  [{'label': 'negative', 'score': 0.8319297432899475}],
#  [{'label': 'negative', 'score': 0.7037416696548462}],
#  [{'label': 'negative', 'score': 0.997649610042572}],
#  [{'label': 'negative', 'score': 0.9527319073677063}],
#  [{'label': 'negative', 'score': 0.9418312311172485}],
#  [{'label': 'negative', 'score': 0.9625726342201233}],
#  [{'label': 'negative', 'score': 0.9908946752548218}],
#  [{'label': 'negative', 'score': 0.9939534068107605}],
#  [{'label': 'negative', 'score': 0.9845235347747803}],
#  [{'label': 'negative', 'score': 0.9973961114883423}],
#  [{'label': 'negative', 'score': 0.9728391170501709}],
#  [{'label': 'positive', 'score': 0.7434529066085815}],
#  [{'label': 'negative', 'score': 0.9983658194541931}],
#  ...]

# %%
labels=[i[0]['label'] for i in sentiment]

# %%
labels
# Out:
# ['negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'negative',
#  'positive',
#  'negative',
#  ...]

# %%
labels_series=pd.Series(labels,name='labels')

# %%
labels_series
# Out:
# 0         negative
# 1         negative
# 2         negative
# 3         negative
# 4         negative
#             ...
# 272198    negative
# 272199    negative
# 272200    positive
# 272201    negative
# 272202    negative
# Name: labels, Length: 272203, dtype: object

# %%
df_wsentiment=pd.concat([df,labels_series],axis=1)

# %%
df_wsentiment
# Out:
#         Unnamed: 0                       date  \
# 0                0  2023-02-12 23:27:26+00:00
# 1                1  2023-02-12 23:21:58+00:00
# 2                2  2023-02-12 23:13:45+00:00
# 3                3  2023-02-12 23:04:45+00:00
# 4                4  2023-02-12 22:57:51+00:00
# ...            ...                        ...
# 272198      272198  2022-10-15 00:31:42+00:00
# 272199      272199  2022-10-15 00:30:59+00:00
# 272200      272200  2022-10-15 00:27:09+00:00
# 272201      272201  2022-10-15 00:21:38+00:00
# 272202      272202  2022-10-15 00:02:53+00:00
#
#                                                rawContent  \
# 0       @medyaadami Yahu ben asgari ücret ile geçimini...
# 1       @zaferozturkfk @TOZOK1951 Özel okul öğretmenle...
# 2       Yandaş medya el ele vermiş "emekliye gün doğdu...
# 3       @kilicdarogluk Ekonomiyi çökerttiler derken Ak...
# 4       @suleerenates @ErSalih55 @yazilama @Besiktas @...
# ...                                                   ...
# 272198  Asgari ücret 2 senede 2 katına çıktı ama işsiz...
# 272199  millet 10 bine az demiş ulan 2 aylık asgari üc...
# 272200  @CreeWarrior2010 Türkiye'de asgari ücret ile b...
# 272201  @adanaliahmo @ebrukucukaydinn Cahil adam. Hesa...
# 272202  @b_ysabri La meta devlet yeteri kadar yani geç...
#
#                          id    labels
# 0       1624913098388774919  negative
# 1       1624911722640293889  negative
# 2       1624909655813107715  negative
# 3       1624907389227921408  negative
# 4       1624905652794449921  negative
# ...                     ...       ...
# 272198  1581080337995960321  negative
# 272199  1581080158286491648  negative
# 272200  1581079194452127744  positive
# 272201  1581077804392726528  negative
# 272202  1581073086878650369  negative
#
# [272203 rows x 5 columns]

# %%
df_wsentiment.to_csv('minwagesentiment3.csv')

# %%
d=pd.read_csv('minwagesentiment3.csv')

# %%
# Out:
#         Unnamed: 0.1  Unnamed: 0                       date  \
# 0                  0           0  2023-02-12 23:27:26+00:00
# 1                  1           1  2023-02-12 23:21:58+00:00
# 2                  2           2  2023-02-12 23:13:45+00:00
# 3                  3           3  2023-02-12 23:04:45+00:00
# 4                  4           4  2023-02-12 22:57:51+00:00
# ...              ...         ...                        ...
# 272198        272198      272198  2022-10-15 00:31:42+00:00
# 272199        272199      272199  2022-10-15 00:30:59+00:00
# 272200        272200      272200  2022-10-15 00:27:09+00:00
# 272201        272201      272201  2022-10-15 00:21:38+00:00
# 272202        272202      272202  2022-10-15 00:02:53+00:00
#
#                                                rawContent  \
# 0       @medyaadami Yahu ben asgari ücret ile geçimini...
# 1       @zaferozturkfk @TOZOK1951 Özel okul öğretmenle...
# 2       Yandaş medya el ele vermiş "emekliye gün doğdu...
# 3       @kilicdarogluk Ekonomiyi çökerttiler derken Ak...
# 4       @suleerenates @ErSalih55 @yazilama @Besiktas @...
# ...                                                   ...
# 272198  Asgari ücret 2 senede 2 katına çıktı ama işsiz...
# 272199  millet 10 bine az demiş ulan 2 aylık asgari üc...
# 272200  @CreeWarrior2010 Türkiye'de asgari ücret ile b...
# 272201  @adanaliahmo @ebrukucukaydinn Cahil adam. Hesa...
# 272202  @b_ysabri La meta devlet yeteri kadar yani geç...
#
#                          id    labels
# 0       1624913098388774919  negative
# 1       1624911722640293889  negative
# 2       1624909655813107715  negative
# 3       1624907389227921408  negative
# 4       1624905652794449921  negative
# ...                     ...       ...
# 272198  1581080337995960321  negative
# 272199  1581080158286491648  negative
# 272200  1581079194452127744  positive
# 272201  1581077804392726528  negative
# 272202  1581073086878650369  negative
#
# [272203 rows x 6 columns]
