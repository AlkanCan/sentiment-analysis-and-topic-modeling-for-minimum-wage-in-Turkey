# %%
tweet_count = 500000
text_query = "asgari ücret"
since_date = "2021-10-15"
until_date = "2022-06-15"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> minwagepr1.json'.format(tweet_count, since_date, text_query, until_date))

# Reads the json generated from the CLI command above and creates a pandas dataframe
min_wage = pd.read_json('minwagepr1.json', lines=True)

# Displays first 5 entries from dataframe
min_wage
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 326053  snscrape.modules.twitter.Tweet
# 326054  snscrape.modules.twitter.Tweet
# 326055  snscrape.modules.twitter.Tweet
# 326056  snscrape.modules.twitter.Tweet
# 326057  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/hakiki_cassey/status/15368...
# 1       https://twitter.com/ulaknews/status/1536858567...
# 2       https://twitter.com/askinncann/status/15368578...
# 3       https://twitter.com/KhalidVelid/status/1536856...
# 4       https://twitter.com/gokturkfurkan20/status/153...
# ...                                                   ...
# 326053  https://twitter.com/berkgulcink/status/1448808...
# ...

# %%
min_wage
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 326053  snscrape.modules.twitter.Tweet
# 326054  snscrape.modules.twitter.Tweet
# 326055  snscrape.modules.twitter.Tweet
# 326056  snscrape.modules.twitter.Tweet
# 326057  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/hakiki_cassey/status/15368...
# 1       https://twitter.com/ulaknews/status/1536858567...
# 2       https://twitter.com/askinncann/status/15368578...
# 3       https://twitter.com/KhalidVelid/status/1536856...
# 4       https://twitter.com/gokturkfurkan20/status/153...
# ...                                                   ...
# 326053  https://twitter.com/berkgulcink/status/1448808...
# ...

# %%
import os
import pandas as pd

# %%
min_wage_1=min_wage[['date','rawContent','id']]

# %%
min_wage_1
# Out:
#                             date  \
# 0      2022-06-14 23:50:27+00:00
# 1      2022-06-14 23:50:10+00:00
# 2      2022-06-14 23:47:28+00:00
# 3      2022-06-14 23:40:25+00:00
# 4      2022-06-14 23:40:12+00:00
# ...                          ...
# 326053 2021-10-15 00:31:42+00:00
# 326054 2021-10-15 00:23:21+00:00
# 326055 2021-10-15 00:22:51+00:00
# 326056 2021-10-15 00:11:08+00:00
# 326057 2021-10-15 00:05:27+00:00
#
#                                                rawContent                   id
# 0       @artaxerxesica Bildiğim kadarıyla orada maaş s...  1536858639675400198
# 1       Asgari ücret için flaş öneri: "Yılda 4 kez art...  1536858567025864704
# 2       Karşı komşumuz asgari ücret ile çalışıyor, 4 k...  1536857889129758720
# 3       @enginozkoc ne kolay ya , asgari ücret artmalı...  1536856111416066048
# 4       yok abi yok allah bizi solculardan ve saçma po...  1536856057208881153
# ...                                                   ...                  ...
# ...

# %%
min_wage_1.to_csv('minimumwagepart1.csv')

# %%
m=pd.read_csv('minimumwagepart1.csv')

# %%
m.to_excel('minimumwagepart1.xlsx')

# %%
mex=pd.read_excel('minimumwagepart1.xlsx')
